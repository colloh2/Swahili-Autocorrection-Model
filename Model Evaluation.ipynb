# %%
pip install snscrape
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: snscrape in c:\users\c\anaconda3\lib\site-packages (0.6.2.20230320)
# Requirement already satisfied: requests[socks] in c:\users\c\anaconda3\lib\site-packages (from snscrape) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\c\anaconda3\lib\site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: filelock in c:\users\c\anaconda3\lib\site-packages (from snscrape) (3.6.0)
# Requirement already satisfied: lxml in c:\users\c\anaconda3\lib\site-packages (from snscrape) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\c\anaconda3\lib\site-packages (from beautifulsoup4->snscrape) (2.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.7.1)

# %%
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
max_tweets = 150
tweets = []

for i, tweet in enumerate(sntwitter.TwitterSearchScraper('from:@bbcswahili').get_items()):
    if i >= max_tweets:
        break
    tweets.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username])

df = pd.DataFrame(tweets, columns=['Datetime', 'Tweet Id', 'Content', 'Username'])

# %%
tweet_df = pd.DataFrame(tweets, columns = ['date', 'id', 'content', 'username'])
tweet_df
# Out:
#                          date                   id  \
# 0   2023-04-01 13:30:07+00:00  1642157394003210248
# 1   2023-04-01 13:00:12+00:00  1642149866796097539
# 2   2023-04-01 12:30:13+00:00  1642142322744864769
# 3   2023-04-01 12:00:15+00:00  1642134780039905286
# 4   2023-04-01 11:30:07+00:00  1642127197467975680
# ..                        ...                  ...
# 145 2023-03-27 18:30:07+00:00  1640420953304776718
# 146 2023-03-27 18:05:42+00:00  1640414807542095877
# 147 2023-03-27 17:30:13+00:00  1640405877998993438
# 148 2023-03-27 17:01:49+00:00  1640398733488668690
# 149 2023-03-27 17:00:22+00:00  1640398365203611661
#
#                                                content    username
# 0    Je 'Siku ya Wajinga' duniani ilianzaje?\nhttps...  bbcswahili
# 1    Wanasayansi waelezea hatari za kifo cha ghafla...  bbcswahili
# 2    'Bado niko hai' Papa Francis atania wakati ali...  bbcswahili
# 3    Ramadhan 2023: Baadhi ya matukio muhimu katika...  bbcswahili
# 4    Mhalifu sugu Kenya ahukumiwa kifongo cha miaka...  bbcswahili
# ..                                                 ...         ...
# 145  Harakati za Raila Odinga na wenzake kuongoza m...  bbcswahili
# 146  Fahamu vyakula ambavyo vikichanganyika tumboni...  bbcswahili
# 147  Chelsea wako tayari kutoa euro milioni 100 kum...  bbcswahili
# 148  Maandamano Kenya: Moto mkubwa wazuka katika sh...  bbcswahili
# 149  Watoto waliomtafutia mume mama yao\n\nhttps://...  bbcswahili
#
# [150 rows x 4 columns]

# %%
tweet_df.to_csv("Swahili Autocorrection Model.csv", index = False)
tweet_df
# Out:
#                          date                   id  \
# 0   2023-04-01 13:30:07+00:00  1642157394003210248
# 1   2023-04-01 13:00:12+00:00  1642149866796097539
# 2   2023-04-01 12:30:13+00:00  1642142322744864769
# 3   2023-04-01 12:00:15+00:00  1642134780039905286
# 4   2023-04-01 11:30:07+00:00  1642127197467975680
# ..                        ...                  ...
# 145 2023-03-27 18:30:07+00:00  1640420953304776718
# 146 2023-03-27 18:05:42+00:00  1640414807542095877
# 147 2023-03-27 17:30:13+00:00  1640405877998993438
# 148 2023-03-27 17:01:49+00:00  1640398733488668690
# 149 2023-03-27 17:00:22+00:00  1640398365203611661
#
#                                                content    username
# 0    Je 'Siku ya Wajinga' duniani ilianzaje?\nhttps...  bbcswahili
# 1    Wanasayansi waelezea hatari za kifo cha ghafla...  bbcswahili
# 2    'Bado niko hai' Papa Francis atania wakati ali...  bbcswahili
# 3    Ramadhan 2023: Baadhi ya matukio muhimu katika...  bbcswahili
# 4    Mhalifu sugu Kenya ahukumiwa kifongo cha miaka...  bbcswahili
# ..                                                 ...         ...
# 145  Harakati za Raila Odinga na wenzake kuongoza m...  bbcswahili
# 146  Fahamu vyakula ambavyo vikichanganyika tumboni...  bbcswahili
# 147  Chelsea wako tayari kutoa euro milioni 100 kum...  bbcswahili
# 148  Maandamano Kenya: Moto mkubwa wazuka katika sh...  bbcswahili
# 149  Watoto waliomtafutia mume mama yao\n\nhttps://...  bbcswahili
#
# [150 rows x 4 columns]

# %%
tweet = tweet_df['content'][124]
print(tweet)
# Out:
# Urusi yaonya Uingereza kutosambaza makombora ya urani iliyorutubishwa kwa Ukraine, ikisema yana "jumuisha nyuklia".
#
# https://t.co/HFPypxwNC3

# %%
tweet_df['content'] = tweet_df['content'].str.replace("[^a-zA-Z#]", " ")

for column in tweet_df.columns:
    tweet_df['content'] = tweet_df['content'].str.replace(r'\W'," ")
# Out:
# C:\Users\C\AppData\Local\Temp\ipykernel_4480\2253038890.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweet_df['content'] = tweet_df['content'].str.replace("[^a-zA-Z#]", " ")
# C:\Users\C\AppData\Local\Temp\ipykernel_4480\2253038890.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweet_df['content'] = tweet_df['content'].str.replace(r'\W'," ")

# %%
tweet_df
# Out:
#                          date                   id  \
# 0   2023-04-01 13:30:07+00:00  1642157394003210248
# 1   2023-04-01 13:00:12+00:00  1642149866796097539
# 2   2023-04-01 12:30:13+00:00  1642142322744864769
# 3   2023-04-01 12:00:15+00:00  1642134780039905286
# 4   2023-04-01 11:30:07+00:00  1642127197467975680
# ..                        ...                  ...
# 145 2023-03-27 18:30:07+00:00  1640420953304776718
# 146 2023-03-27 18:05:42+00:00  1640414807542095877
# 147 2023-03-27 17:30:13+00:00  1640405877998993438
# 148 2023-03-27 17:01:49+00:00  1640398733488668690
# 149 2023-03-27 17:00:22+00:00  1640398365203611661
#
#                                                content    username
# 0    Je 'Siku ya Wajinga' duniani ilianzaje?\nhttps...  bbcswahili
# 1    Wanasayansi waelezea hatari za kifo cha ghafla...  bbcswahili
# 2    'Bado niko hai' Papa Francis atania wakati ali...  bbcswahili
# 3    Ramadhan 2023: Baadhi ya matukio muhimu katika...  bbcswahili
# 4    Mhalifu sugu Kenya ahukumiwa kifongo cha miaka...  bbcswahili
# ..                                                 ...         ...
# 145  Harakati za Raila Odinga na wenzake kuongoza m...  bbcswahili
# 146  Fahamu vyakula ambavyo vikichanganyika tumboni...  bbcswahili
# 147  Chelsea wako tayari kutoa euro milioni 100 kum...  bbcswahili
# 148  Maandamano Kenya: Moto mkubwa wazuka katika sh...  bbcswahili
# 149  Watoto waliomtafutia mume mama yao\n\nhttps://...  bbcswahili
#
# [150 rows x 4 columns]

# %%
import re
from nltk.stem import PorterStemmer
    
tokenized_tweet = tweet_df['content'].apply(lambda x: x.split())

stemmer = PorterStemmer()

stemmed_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(token) for token in x])

swahili_stop_words = ['ya', 'na', 'kwa', 'ni', 'wa', 'wake', 'ya', 'yake', 'yangu', 'yao', 'yeye', 'yote', 'yoyote', 'yule', 'za', 'zaidi', 'zake', 'zangu', 'za', 'zipi', 'zote']
filtered_tweet = stemmed_tweet.apply(lambda x: [word for word in x if word not in swahili_stop_words])
filtered_tweet
# Out:
# 0      [je, 'siku, wajinga', duniani, ilianzaje?, htt...
# 1      [wanasayansi, waelezea, hatari, kifo, cha, gha...
# 2      ['bado, niko, hai', papa, franci, atania, waka...
# 3      [ramadhan, 2023:, baadhi, matukio, muhimu, kat...
# 4      [mhalifu, sugu, kenya, ahukumiwa, kifongo, cha...
#                              ...
# 145    [harakati, raila, odinga, wenzak, kuongoza, ma...
# 146    [fahamu, vyakula, ambavyo, vikichanganyika, tu...
# 147    [chelsea, wako, tayari, kutoa, euro, milioni, ...
# 148    [maandamano, kenya:, moto, mkubwa, wazuka, kat...
# 149    [watoto, waliomtafutia, mume, mama, https://t....
# Name: content, Length: 150, dtype: object

# %%
import re
from nltk.stem import PorterStemmer
import pandas as pd

def preprocess_text(tweet_df):
    tokenized_tweet = tweet_df['content'].apply(lambda x: x.split())

    stemmer = PorterStemmer()

    stemmed_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(token) for token in x])

    swahili_stop_words = ['ya', 'na', 'kwa', 'ni', 'wa', 'wake', 'ya', 'yake', 'yangu', 'yao', 'yeye', 'yote', 'yoyote', 'yule', 'za', 'zaidi', 'zake', 'zangu', 'za', 'zipi', 'zote']
    
    filtered_tweet = stemmed_tweet.apply(lambda x: [word for word in x if word not in swahili_stop_words])

    tweet_df['filtered_tokens'] = filtered_tweet
    
    tweet_df['preprocessed_text'] = tweet_df['filtered_tokens'].apply(lambda x: ' '.join(x))
    
    return tweet_df
    

    tweet_df = pd.read_csv('Swahili Autocorrection Model.csv')

    preprocessed_tweet_df = preprocess_text(tweet_df)

    preprocessed_tweet_df.to_csv('preprocessed_tweets.csv', index=False)

# %%
import pandas as pd
import numpy as np
import random
import re
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


preprocessed_tweet_df = pd.read_csv('preprocessed_tweets.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(preprocessed_tweet_df['preprocessed_text'], preprocessed_tweet_df['content'], test_size=0.3, random_state=42)

vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

nb_model = MultinomialNB()
nb_model.fit(X_train_vec, y_train)

y_pred = nb_model.predict(X_test_vec)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)

# %%
from sklearn.metrics import classification_report

y_pred = nb_model.predict(X_test_vec)
print(classification_report(y_test, y_pred))
# Out:
#                                                                                                                                                                                                                                                                                                          precision    recall  f1-score   support
#
#                                                                       #NipasheWikendi  USAFI KWA WANAUME NI KAMA MAFUTA NA MAJI MAANA WASIPOKUWA NA WASAIDIZI (MKE) BASI TUSEME YOTE NI VANITY!!TWAJIVUNIA KUWA WAKE SENT FROM HEAVEN NA TUHESHIMIWE SANA!!🤙 @citizentvkenya @RashidAbdalla @LuluHassan       0.00      0.00      0.00         1
#                                          #NipasheWikendi @LuluHassan @RashidAbdalla @citizentvkenya Hujambo.. mambo mengine hufichwa kabisa sababu isemwe kwa sasa huweza kuvunja mahusiono na heshima kwa ndoa . Tuna historia chafu @benjamin let old cans be sealed completely. From Diaspora Rongai       0.00      0.00      0.00         1
#                                                #NipasheWikendi on the issue of clashes let the govt divide off whole of the land and issues title deeds. The idea of community ownership of land isn't working..let residents device other activities away from pastoralism..eg bring up dams for agric       0.00      0.00      0.00         1
#                                                                                                                                                                                     #NipasheWikendi this chille from TZ lacks a funny bone. Wengine wakiangua kicheko mamma ameseti sura ya mawe I say.       0.00      0.00      0.00         1
#                                                                                                       #nipashewikendi   ni vyema kuwasaidia wanafunzi wanaokosa karo kwenda shuleni....kwa hivyo basi consider our own student from choronok kuresoi north kamara ward ila kwangu naitwa collins thanks       0.00      0.00      0.00         1
#                                                                                                 @DrGoaMmoja @citizentvkenya @LuluHassan Heko Heko kwa serikali @citizentvkenya @LuluHassan Watching from Kaboi kiptulus Nandi
# Naunga mkono chanjo ikuwe lazima kwa kila mtu hapa Nchini #NipasheWikendi       0.00      0.00      0.00         0
#                                                                                                         @Gracetoroitich1 @LuluHassan @RashidAbdalla @citizentvkenya From moisbridge kapkoi streaming live.. Am in love with the conversation @RashidAbdalla @LuluHassan @citizentvkenya #NipasheWikendi       0.00      0.00      0.00         0
#                                     @JembeniL @Emeje5 @citizentvkenya @RashidAbdalla @LuluHassan @RashidAbdalla @citizentvkenya #Nipashewikendi @LuluHassan @RashidAbdalla Watching from kiptulus Nandi
# Tafadhali serikali iweke usalama wa kutosha marakweet wahusika wachukuliwe hatua kali ya sheria       0.00      0.00      0.00         0
#                                                                                      @LuluHassan @RashidAbdalla @citizentvkenya #Nipashewikendi @LuluHassan @RashidAbdalla Watching from kiptulus Nandi
# Tafadhali serikali iweke usalama wa kutosha marakweet wahusika wachukuliwe hatua kali ya sheria       0.00      0.00      0.00         1
#                                                                                                                                                    @LuluHassan @citizentvkenya @LuluHassan Watching from Kaboi kiptulus Nandi
# Naunga mkono chanjo ikuwe lazima kwa kila mtu hapa Nchini #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                              @RichardHamisi1 @LuluHassan @RashidAbdalla Following from Njoro sub county #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                           @citizentvkenya
# @LuluHassan
# @RashidAbdalla
# #nipashewikendi
# Fisi hakuwa na shida , Following from kona mbaya jua kali turbo       0.00      0.00      0.00         1
#                                                                                                                                                   @citizentvkenya  happy fathers day to Stanley Barasa from kawalun village Teso North and I myself Baraza Etiang here at salgaa Nakuru.#NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                                                              @citizentvkenya #NipasheWikendi Watching from ukunda diani       0.00      0.00      0.00         1
#                                                                                                                                                                                                                 @citizentvkenya #Nipashewikendi @LuluHassan @RashidAbdalla Watching from kiptulus Nandi       0.00      0.00      0.00         1
#                                                                                                                     @citizentvkenya #Nipashewikendi @LuluHassan @RashidAbdalla Watching from kiptulus Nandi niko na miaka 10 kwa ndoa na nilimwoa msichana sasa ni bibi wangu akiwa na umri mdogo 15 ✊✊       1.00      1.00      1.00         1
#                                                                                                                                                                                                               @citizentvkenya @LuluHassan @RashidAbdalla Closely tuned in from Nairobi.
# #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                             @citizentvkenya @LuluHassan Hiyo ni hatua nzuri sana...watu wajitokeze waanze kuchanjwa sasa..Bila chanjo hakuna huduma,suluhisho ni kuchukua chanjo ili upate cheti...tuned from Kapsabet, #Nipashewikendi       0.00      0.00      0.00         1
#                                                                                                                                                                @citizentvkenya @LuluHassan Watching from Kaboi kiptulus Nandi
# Naunga mkono chanjo ikuwe lazima kwa kila mtu hapa Nchini #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                                               @citizentvkenya @MKapombe Following from Njoro Sub County #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                        @citizentvkenya @MKapombe Happy new year from me Kapombe #NipasheWikendi https://t.co/kjDKxi8lrK       0.00      0.00      0.00         1
#                                                                                                                                                                                                 @citizentvkenya @MKapombe Live watching from kitengela 👀like your Swahili news #NipasheWikendi@Mkapombe       0.00      0.00      0.00         1
#                                                                                                                                                                                                                                @citizentvkenya @MKapombe Watching from Njoro Sub County #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                              @citizentvkenya @RashidAbdalla @LuluHassan #NipasheWikendi watching citizen tv from Doha Qatar,, namtakia Gentris Savai heri njema Kwa kcse (muyrere mixed secondary school) vihiga county       0.00      0.00      0.00         1
#                                                                                                                                                                                                              @citizentvkenya @RashidAbdalla @LuluHassan Following from Njoro Sub County #NipasheWikendi       0.00      0.00      0.00         1
#                                                                  @citizentvkenya @RashidAbdalla @LuluHassan Gatuso from Mishomoroni Msa. Watu waache kujitetea. Lazima watu wakue akili. Kwa nini Kitanda kikawekwa bedroom na meza ikawekwa sitting room?
# @citizentvkenya
# #NipasheWikendi
# @LuluHassan       0.00      0.00      0.00         1
#                                                                                                                                                               @citizentvkenya @RashidAbdalla @LuluHassan Good evening from Endebess ,,Best wishes tu all skuls in Endebess Constituency #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                              @citizentvkenya @RashidAbdalla @LuluHassan Watching from Endebess ,, Khali la heri kwa shule na wathainiwa wote hapa Endebess Constituency #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                                  @citizentvkenya @RashidAbdalla @LuluHassan Watching live from endebess #NipasheWikendi       0.00      0.00      0.00         2
#                                                                                                                                                                                    @citizentvkenya @RashidAbdalla @WChebukati atakumbukwa Sana kwa kazi nzuri ,, watching from Endebess #NipasheWikendi       0.00      0.00      0.00         0
#                                                                                                                                                                                                                          @citizentvkenya @RashidAbdalla Following from Njoro Sub County #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                      @citizentvkenya @RashidAbdalla Happy Christmas from me @RashidAbdalla  ,,,  watching from Endebess #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                               @citizentvkenya @RashidAbdalla Kwa kweli @RashidAbdalla   Mr @WChebukati  atakumbukwa sana kwa kazi nzuri ,,, watching live from Endebess #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                                      @citizentvkenya All the way from bukura kakamega county Niko tuned.#nipashewikendi       0.00      0.00      0.00         1
#                                                      @citizentvkenya COVID-19 in Kenya got some funny trend but anyway I'm a commoner with no say but let's now focus on how Kenya is going to recover from this economic crisis brought by Corruption during this pandemic #nipashewikendi @LuluHassan       0.00      0.00      0.00         1
# @citizentvkenya Equinox is when the LENGTH of days and nights IS EQUAL ie equinox
# It can also be described as the period when the sun is overhead at the equator, meaning that places near the equator tent to experience high temperature range from the usual. Mugai Kabras watching.
# #NipasheWikendi       0.00      0.00      0.00         0
#                                                                                                                                                                                                                                         @citizentvkenya Following from Njoro Sub County #NipasheWikendi       0.03      1.00      0.06         1
#                                                                                                                                  @citizentvkenya These men that runs away from responsibilities  should be on the front line waiting for this contraceptive #NipasheWikendi  @LuluHassan @RashidAbdalla       0.00      0.00      0.00         1
#                                                                                                                                                                                                                                              @citizentvkenya Tuned liiive from kitale..
# #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                                                          @citizentvkenya Watching from Njoro Sub County #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                                            @citizentvkenya Watching live from Kianyabao Nyamira county.
# #nipashewikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                                               @citizentvkenya Watching live from kimose near Emining ,, #Nipashewikendi       0.00      0.00      0.00         1
#                                                                                                                                                                    @citizentvkenya Wishing success  to lorine  jelagat from uasin gishu  at shinners academy and to all the candidates
# #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                               @citizentvkenya Wishing success to my brother Hakim Dido from Nanyuki DEB #NipasheWikendi       0.00      0.00      0.00         1
#                                                                                                                                                                @citizentvkenya Wishing success to my sister Lilian from githunguri jetview primary and all candidates from Ruai primary #NipasheWikendi       0.00      0.00      0.00         0
#                                                                                            @citizentvkenya yaliyopita hakuna haja ya kuelezea tena, utavunja imani kwenye mahusiano yenu punde tu utamuelezea mpenzi wako kuhusi yule ulie kuwa nae awali, watching from kibomet kitale
# #nipashewikendi       0.00      0.00      0.00         1
#                                                                                                                      @mercy_kibet @RashidAbdalla @citizentvkenya @LuluHassan From moisbridge kapkoi watching live... #NipasheWikendi @RashidAbdalla @LuluHassan @citizentvkenya mazungumzo murwa kabiza       0.00      0.00      0.00         1
#                                                                                                                                      From Embu, naomba wakenya  wote tutii kanuni ,za wizara ya afya, tandavu ya Corona imezidi..na tuombe mungu atusaidie
# #nipashewikendi
# @citizentvkenya
# @LuluHassan       0.00      0.00      0.00         1
#                                                                                                                                               From purity's #SilahaMtaani expose, we can conclude we are not safe @LuluHassan @RashidAbdalla @citizentvkenya Purity apewe security sasa #nipashewikendi       0.00      0.00      0.00         1
#                                                                                                                                                                                                                          Watching live from Lugari Mbagara,naipenda sana hii longalonga #NipasheWikendi       0.00      0.00      0.00         1
#
#                                                                                                                                                                                                                                                                                                accuracy                           0.04        45
#                                                                                                                                                                                                                                                                                               macro avg       0.02      0.04      0.02        45
#                                                                                                                                                                                                                                                                                            weighted avg       0.02      0.04      0.02        45
# C:\Users\C\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\C\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\C\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\C\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\C\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\C\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
