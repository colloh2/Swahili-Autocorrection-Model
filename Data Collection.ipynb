# %%
pip install snscrape
# Out:
# Requirement already satisfied: snscrape in c:\users\c\anaconda3\lib\site-packages (0.6.2.20230320)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: beautifulsoup4 in c:\users\c\anaconda3\lib\site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: lxml in c:\users\c\anaconda3\lib\site-packages (from snscrape) (4.9.1)
# Requirement already satisfied: filelock in c:\users\c\anaconda3\lib\site-packages (from snscrape) (3.6.0)
# Requirement already satisfied: requests[socks] in c:\users\c\anaconda3\lib\site-packages (from snscrape) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\c\anaconda3\lib\site-packages (from beautifulsoup4->snscrape) (2.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.26.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\c\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.7.1)

# %%
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
max_tweets = 150
tweets = []

for i, tweet in enumerate(sntwitter.TwitterSearchScraper('from:@bbcswahili').get_items()):
    if i >= max_tweets:
        break
    tweets.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username])

df = pd.DataFrame(tweets, columns=['Datetime', 'Tweet Id', 'Content', 'Username'])

# %%
tweet_df = pd.DataFrame(tweets, columns = ['date', 'id', 'content', 'username'])
tweet_df
# Out:
#                          date                   id  \
# 0   2023-04-01 13:30:07+00:00  1642157394003210248
# 1   2023-04-01 13:00:12+00:00  1642149866796097539
# 2   2023-04-01 12:30:13+00:00  1642142322744864769
# 3   2023-04-01 12:00:15+00:00  1642134780039905286
# 4   2023-04-01 11:30:07+00:00  1642127197467975680
# ..                        ...                  ...
# 145 2023-03-27 18:30:07+00:00  1640420953304776718
# 146 2023-03-27 18:05:42+00:00  1640414807542095877
# 147 2023-03-27 17:30:13+00:00  1640405877998993438
# 148 2023-03-27 17:01:49+00:00  1640398733488668690
# 149 2023-03-27 17:00:22+00:00  1640398365203611661
#
#                                                content    username
# 0    Je 'Siku ya Wajinga' duniani ilianzaje?\nhttps...  bbcswahili
# 1    Wanasayansi waelezea hatari za kifo cha ghafla...  bbcswahili
# 2    'Bado niko hai' Papa Francis atania wakati ali...  bbcswahili
# 3    Ramadhan 2023: Baadhi ya matukio muhimu katika...  bbcswahili
# 4    Mhalifu sugu Kenya ahukumiwa kifongo cha miaka...  bbcswahili
# ..                                                 ...         ...
# 145  Harakati za Raila Odinga na wenzake kuongoza m...  bbcswahili
# 146  Fahamu vyakula ambavyo vikichanganyika tumboni...  bbcswahili
# 147  Chelsea wako tayari kutoa euro milioni 100 kum...  bbcswahili
# 148  Maandamano Kenya: Moto mkubwa wazuka katika sh...  bbcswahili
# 149  Watoto waliomtafutia mume mama yao\n\nhttps://...  bbcswahili
#
# [150 rows x 4 columns]
